# %% [markdown]
# # Bashbot Notebook
#
# For this chatbot I will be using bash man pages, tealdeer output and the output from the bash help system for builtin commands.
#
# There will need to be 2 pipelines.
# - The first will be the data ingestion pipeline.
# - Then we will need a query pipeline that will use our domain specific emnbeddings as the context for an LLM prompt. This is the RAG implementation that will be built.

# %% [markdown]
# ## Data Ingestion Pipeline

# %% [markdown]
# ### Imports

# %%
import os
import sys
import langchain
from openai import OpenAI

# %% [markdown]
# #### Notebook Exploration

# %% [markdown]
# Ingesting data

# %% [markdown]
# Chunking

# %% [markdown]
# Embedding

# %% [markdown]
# Storing in vector db

# %% [markdown]
# ## Prompt and RAG Retrieval Pipeline
